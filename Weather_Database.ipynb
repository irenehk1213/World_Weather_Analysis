# %%
# PART 1: Get the weather description & amount of participation for each city.

## Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import city module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 616

# %%
# Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.(add "units=imperial")
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=526f2b8b4b6552d3b0247d7263bbcf9d

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Edinburgh"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=526f2b8b4b6552d3b0247d7263bbcf9d&q=Edinburgh

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-3.2,"lat":55.95},"weather":[{"id":520,"main":"Rain","description":"light intensity shower rain","icon":"09n"}],"base":"stations","main":{"temp":37.51,"feels_like":19.63,"temp_min":35.6,"temp_max":39.2,"pressure":1004,"humidity":65},"visibility":10000,"wind":{"speed":24.16,"deg":250,"gust":40.26},"rain":{"1h":0.34},"clouds":{"all":40},"dt":1582394066,"sys":{"type":1,"id":1442,"country":"GB","sunrise":1582356195,"sunset":1582392590},"timezone":0,"id":2650225,"name":"Edinburgh","cod":200}'

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -3.2, 'lat': 55.95},
#  'weather': [{'id': 520,
#    'main': 'Rain',
#    'description': 'light intensity shower rain',
#    'icon': '09n'}],
#  'base': 'stations',
#  'main': {'temp': 37.51,
#   'feels_like': 19.63,
#   'temp_min': 35.6,
#   'temp_max': 39.2,
#   'pressure': 1004,
#   'humidity': 65},
#  'visibility': 10000,
#  'wind': {'speed': 24.16, 'deg': 250, 'gust': 40.26},
#  'rain': {'1h': 0.34},
#  'clouds': {'all': 40},
#  'dt': 1582394066,
#  'sys': {'type': 1,
#   'id': 1442,
#   'country': 'GB',
#   'sunrise': 1582356195,
#   'sunset': 1582392590},
#  'timezone': 0,
#  'id': 2650225,
#  'name': 'Edinburgh',
#  'cod': 200}

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        try: 
            city_rain = city_weather ["rain"]["3h"]
        except: 
            city_rain = 0 

        try:
            city_snow = city_weather ["snow"]["3h"]
        except: 
            city_snow = 0 
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain inches (last 3 hrs)": city_rain,
                          "Snow inches (last 3 hrs)": city_snow})
    except:
        print("City not found")
        pass 
    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | bardiyah
# Processing Record 5 of Set 1 | sao gabriel da cachoeira
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | nuuk
# Processing Record 8 of Set 1 | brigantine
# Processing Record 9 of Set 1 | arman
# Processing Record 10 of Set 1 | mabaruma
# Processing Record 11 of Set 1 | belushya guba
# City not found
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | bathsheba
# Processing Record 15 of Set 1 | liboro
# Processing Record 16 of Set 1 | lata
# Processing Record 17 of Set 1 | riihimaki
# Processing Record 18 of Set 1 | zhangye
# Processing Record 19 of Set 1 | northam
# Processing Record 20 of Set 1 | nouadhibou
# Processing Record 21 of Set 1 | lodwar
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | iisalmi
# Processing Record 24 of Set 1 | acapulco
# Processing Record 25 of Set 1 | taolanaro
# City not found
# Processing Record 26 of Set 1 | darnah
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | peniche
# Processing Record 29 of Set 1 | guerrero negro
# Processing Record 30 of Set 1 | sisimiut
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | atar
# Processing Record 36 of Set 1 | balsas
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | almaznyy
# Processing Record 40 of Set 1 | mys shmidta
# City not found
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | siparia
# Processing Record 45 of Set 1 | chimbote
# Processing Record 46 of Set 1 | rundu
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | port blair
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | bintulu
# Processing Record 1 of Set 2 | tsihombe
# City not found
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found
# Processing Record 3 of Set 2 | madisonville
# Processing Record 4 of Set 2 | ivanjica
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | salalah
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | mayya
# Processing Record 11 of Set 2 | sakaiminato
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | ambilobe
# Processing Record 15 of Set 2 | esperance
# Processing Record 16 of Set 2 | sentyabrskiy
# City not found
# Processing Record 17 of Set 2 | arraial do cabo
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | port-gentil
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | khor
# Processing Record 22 of Set 2 | xining
# Processing Record 23 of Set 2 | luebo
# Processing Record 24 of Set 2 | marcona
# City not found
# Processing Record 25 of Set 2 | hornepayne
# Processing Record 26 of Set 2 | cabedelo
# Processing Record 27 of Set 2 | sao filipe
# Processing Record 28 of Set 2 | visby
# Processing Record 29 of Set 2 | djibo
# Processing Record 30 of Set 2 | rikitea
# Processing Record 31 of Set 2 | luena
# Processing Record 32 of Set 2 | honiara
# Processing Record 33 of Set 2 | rio gallegos
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | iwanai
# Processing Record 38 of Set 2 | teya
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | marzuq
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | fallon
# Processing Record 43 of Set 2 | nantucket
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | isiro
# Processing Record 48 of Set 2 | bongandanga
# Processing Record 49 of Set 2 | kununurra
# Processing Record 50 of Set 2 | marienburg
# Processing Record 1 of Set 3 | shingu
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | barentsburg
# City not found
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | zhigansk
# Processing Record 6 of Set 3 | bairiki
# Processing Record 7 of Set 3 | dombarovskiy
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | saint-francois
# Processing Record 10 of Set 3 | grand river south east
# City not found
# Processing Record 11 of Set 3 | dvinskoy
# Processing Record 12 of Set 3 | murmashi
# Processing Record 13 of Set 3 | tornio
# Processing Record 14 of Set 3 | lolua
# City not found
# Processing Record 15 of Set 3 | salinas
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | loikaw
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | kahului
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | magaria
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | pacific grove
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | atuona
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | oudtshoorn
# Processing Record 29 of Set 3 | attawapiskat
# City not found
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | warqla
# City not found
# Processing Record 32 of Set 3 | alpena
# Processing Record 33 of Set 3 | tigil
# Processing Record 34 of Set 3 | isparta
# Processing Record 35 of Set 3 | vostok
# Processing Record 36 of Set 3 | aden
# Processing Record 37 of Set 3 | nizhneyansk
# City not found
# Processing Record 38 of Set 3 | emirdag
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | yulara
# Processing Record 41 of Set 3 | dudinka
# Processing Record 42 of Set 3 | caraballeda
# Processing Record 43 of Set 3 | kavieng
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | znin
# Processing Record 46 of Set 3 | sadasivpet
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | nizwa
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | dourados
# Processing Record 1 of Set 4 | kalmunai
# Processing Record 2 of Set 4 | zhaoyang
# Processing Record 3 of Set 4 | pemberton
# Processing Record 4 of Set 4 | port-de-bouc
# Processing Record 5 of Set 4 | lambari
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | urumqi
# Processing Record 8 of Set 4 | bindura
# Processing Record 9 of Set 4 | kochki
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | bandarbeyla
# Processing Record 12 of Set 4 | ust-kamchatsk
# City not found
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | olinda
# Processing Record 16 of Set 4 | samusu
# City not found
# Processing Record 17 of Set 4 | susangerd
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | shenjiamen
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | bima
# Processing Record 22 of Set 4 | rosetta
# Processing Record 23 of Set 4 | vila velha
# Processing Record 24 of Set 4 | point pedro
# Processing Record 25 of Set 4 | akyab
# Processing Record 26 of Set 4 | ixtapa
# Processing Record 27 of Set 4 | fairbanks
# Processing Record 28 of Set 4 | faya
# Processing Record 29 of Set 4 | atasu
# Processing Record 30 of Set 4 | georgetown
# Processing Record 31 of Set 4 | hare bay
# Processing Record 32 of Set 4 | kamenskoye
# City not found
# Processing Record 33 of Set 4 | hobyo
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | kilindoni
# Processing Record 36 of Set 4 | nyurba
# Processing Record 37 of Set 4 | longyearbyen
# Processing Record 38 of Set 4 | olafsvik
# Processing Record 39 of Set 4 | tumannyy
# City not found
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | flinders
# Processing Record 42 of Set 4 | maceio
# Processing Record 43 of Set 4 | tan an
# Processing Record 44 of Set 4 | asau
# Processing Record 45 of Set 4 | mehamn
# Processing Record 46 of Set 4 | point pleasant
# Processing Record 47 of Set 4 | koslan
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | sept-iles
# Processing Record 50 of Set 4 | pevek
# Processing Record 1 of Set 5 | rostovka
# Processing Record 2 of Set 5 | portland
# Processing Record 3 of Set 5 | manggar
# Processing Record 4 of Set 5 | saint-joseph
# Processing Record 5 of Set 5 | shablykino
# Processing Record 6 of Set 5 | mandurah
# Processing Record 7 of Set 5 | mirnyy
# Processing Record 8 of Set 5 | vila
# Processing Record 9 of Set 5 | moose factory
# Processing Record 10 of Set 5 | moen
# Processing Record 11 of Set 5 | milkovo
# Processing Record 12 of Set 5 | halalo
# City not found
# Processing Record 13 of Set 5 | tuktoyaktuk
# Processing Record 14 of Set 5 | vila praia de ancora
# Processing Record 15 of Set 5 | eenhana
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | gubin
# Processing Record 18 of Set 5 | cap malheureux
# Processing Record 19 of Set 5 | te anau
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | san carlos de bariloche
# Processing Record 22 of Set 5 | karauzyak
# City not found
# Processing Record 23 of Set 5 | shimoda
# Processing Record 24 of Set 5 | north bend
# Processing Record 25 of Set 5 | santa vitoria do palmar
# Processing Record 26 of Set 5 | hihifo
# City not found
# Processing Record 27 of Set 5 | alta floresta
# Processing Record 28 of Set 5 | wasilla
# Processing Record 29 of Set 5 | camrose
# Processing Record 30 of Set 5 | conde
# Processing Record 31 of Set 5 | razole
# Processing Record 32 of Set 5 | takoradi
# Processing Record 33 of Set 5 | umzimvubu
# City not found
# Processing Record 34 of Set 5 | peace river
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | selma
# Processing Record 38 of Set 5 | tawau
# Processing Record 39 of Set 5 | broken hill
# Processing Record 40 of Set 5 | calvinia
# Processing Record 41 of Set 5 | qaanaaq
# Processing Record 42 of Set 5 | ucluelet
# Processing Record 43 of Set 5 | rocha
# Processing Record 44 of Set 5 | abong mbang
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | bulgan
# Processing Record 47 of Set 5 | oum hadjer
# Processing Record 48 of Set 5 | amursk
# Processing Record 49 of Set 5 | yar-sale
# Processing Record 50 of Set 5 | araouane
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | hithadhoo
# Processing Record 3 of Set 6 | pangkalanbuun
# Processing Record 4 of Set 6 | talaya
# Processing Record 5 of Set 6 | azar shahr
# City not found
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | axim
# Processing Record 8 of Set 6 | san andres
# Processing Record 9 of Set 6 | codrington
# Processing Record 10 of Set 6 | hambantota
# Processing Record 11 of Set 6 | cururupu
# Processing Record 12 of Set 6 | kruisfontein
# Processing Record 13 of Set 6 | husavik
# Processing Record 14 of Set 6 | mareeba
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | preobrazheniye
# Processing Record 17 of Set 6 | louisbourg
# City not found
# Processing Record 18 of Set 6 | ngunguru
# Processing Record 19 of Set 6 | muros
# Processing Record 20 of Set 6 | fortuna
# Processing Record 21 of Set 6 | uige
# Processing Record 22 of Set 6 | severo-kurilsk
# Processing Record 23 of Set 6 | sioux lookout
# Processing Record 24 of Set 6 | nikolskoye
# Processing Record 25 of Set 6 | saravena
# Processing Record 26 of Set 6 | bejar
# Processing Record 27 of Set 6 | tolaga bay
# Processing Record 28 of Set 6 | itamaraca
# Processing Record 29 of Set 6 | batagay-alyta
# Processing Record 30 of Set 6 | clemencia
# Processing Record 31 of Set 6 | mathathane
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | yatou
# Processing Record 34 of Set 6 | kadykchan
# City not found
# Processing Record 35 of Set 6 | vao
# Processing Record 36 of Set 6 | auki
# Processing Record 37 of Set 6 | faanui
# Processing Record 38 of Set 6 | talnakh
# Processing Record 39 of Set 6 | bengkulu
# Processing Record 40 of Set 6 | aripuana
# Processing Record 41 of Set 6 | alugan
# Processing Record 42 of Set 6 | naftah
# City not found
# Processing Record 43 of Set 6 | norman wells
# Processing Record 44 of Set 6 | zhoucheng
# Processing Record 45 of Set 6 | puerto escondido
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | havre-saint-pierre
# Processing Record 49 of Set 6 | aranos
# Processing Record 50 of Set 6 | chernyshevskiy
# Processing Record 1 of Set 7 | pochutla
# Processing Record 2 of Set 7 | kailahun
# Processing Record 3 of Set 7 | alofi
# Processing Record 4 of Set 7 | mwinilunga
# Processing Record 5 of Set 7 | anito
# Processing Record 6 of Set 7 | agaro
# Processing Record 7 of Set 7 | arlit
# Processing Record 8 of Set 7 | barawe
# City not found
# Processing Record 9 of Set 7 | provideniya
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | puerto narino
# Processing Record 12 of Set 7 | dharchula
# Processing Record 13 of Set 7 | karaton
# Processing Record 14 of Set 7 | meyungs
# City not found
# Processing Record 15 of Set 7 | cayenne
# Processing Record 16 of Set 7 | alterosa
# Processing Record 17 of Set 7 | birao
# Processing Record 18 of Set 7 | tezu
# Processing Record 19 of Set 7 | moerai
# Processing Record 20 of Set 7 | eureka
# Processing Record 21 of Set 7 | ocos
# Processing Record 22 of Set 7 | fort nelson
# Processing Record 23 of Set 7 | vaitupu
# City not found
# Processing Record 24 of Set 7 | belaya gora
# Processing Record 25 of Set 7 | yingkou
# Processing Record 26 of Set 7 | ambodifototra
# City not found
# Processing Record 27 of Set 7 | coquimbo
# Processing Record 28 of Set 7 | palabuhanratu
# City not found
# Processing Record 29 of Set 7 | krasnoselkup
# Processing Record 30 of Set 7 | shubarkuduk
# Processing Record 31 of Set 7 | stavern
# Processing Record 32 of Set 7 | amderma
# City not found
# Processing Record 33 of Set 7 | taltal
# Processing Record 34 of Set 7 | ambanja
# Processing Record 35 of Set 7 | port shepstone
# Processing Record 36 of Set 7 | mansa
# Processing Record 37 of Set 7 | luxor
# Processing Record 38 of Set 7 | marrakesh
# Processing Record 39 of Set 7 | camabatela
# Processing Record 40 of Set 7 | hirado
# Processing Record 41 of Set 7 | ancud
# Processing Record 42 of Set 7 | alvorada
# Processing Record 43 of Set 7 | upernavik
# Processing Record 44 of Set 7 | mnogovershinnyy
# Processing Record 45 of Set 7 | seoul
# Processing Record 46 of Set 7 | mogok
# Processing Record 47 of Set 7 | boulsa
# Processing Record 48 of Set 7 | bonavista
# Processing Record 49 of Set 7 | port hedland
# Processing Record 50 of Set 7 | hualmay
# Processing Record 1 of Set 8 | solnechnyy
# Processing Record 2 of Set 8 | hillsboro
# Processing Record 3 of Set 8 | hovd
# Processing Record 4 of Set 8 | umm kaddadah
# Processing Record 5 of Set 8 | vanimo
# Processing Record 6 of Set 8 | roald
# Processing Record 7 of Set 8 | narsaq
# Processing Record 8 of Set 8 | ferrol
# Processing Record 9 of Set 8 | bay city
# Processing Record 10 of Set 8 | ciudad bolivar
# Processing Record 11 of Set 8 | itoman
# Processing Record 12 of Set 8 | mantua
# Processing Record 13 of Set 8 | ures
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | hasaki
# Processing Record 16 of Set 8 | san policarpo
# Processing Record 17 of Set 8 | adrar
# Processing Record 18 of Set 8 | tabou
# Processing Record 19 of Set 8 | aksu
# Processing Record 20 of Set 8 | mahbubabad
# Processing Record 21 of Set 8 | matucana
# Processing Record 22 of Set 8 | padang
# Processing Record 23 of Set 8 | comodoro rivadavia
# Processing Record 24 of Set 8 | houma
# Processing Record 25 of Set 8 | irece
# Processing Record 26 of Set 8 | neiafu
# Processing Record 27 of Set 8 | hofn
# Processing Record 28 of Set 8 | xiamen
# Processing Record 29 of Set 8 | salina
# Processing Record 30 of Set 8 | nefteabad
# City not found
# Processing Record 31 of Set 8 | tautira
# Processing Record 32 of Set 8 | mitsamiouli
# Processing Record 33 of Set 8 | komsomolskiy
# Processing Record 34 of Set 8 | bijie
# Processing Record 35 of Set 8 | dinguiraye
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | eldorado
# Processing Record 38 of Set 8 | gat
# Processing Record 39 of Set 8 | neuquen
# Processing Record 40 of Set 8 | tubuala
# Processing Record 41 of Set 8 | merauke
# Processing Record 42 of Set 8 | saquarema
# Processing Record 43 of Set 8 | tocache
# Processing Record 44 of Set 8 | ivanava
# Processing Record 45 of Set 8 | agadez
# Processing Record 46 of Set 8 | mindelo
# Processing Record 47 of Set 8 | bay saint louis
# Processing Record 48 of Set 8 | saint-augustin
# Processing Record 49 of Set 8 | voznesenye
# Processing Record 50 of Set 8 | matara
# Processing Record 1 of Set 9 | tayoltita
# Processing Record 2 of Set 9 | port huron
# Processing Record 3 of Set 9 | moctezuma
# Processing Record 4 of Set 9 | victoria
# Processing Record 5 of Set 9 | blagodatnoye
# Processing Record 6 of Set 9 | ankazobe
# Processing Record 7 of Set 9 | kloulklubed
# Processing Record 8 of Set 9 | severobaykalsk
# Processing Record 9 of Set 9 | san patricio
# Processing Record 10 of Set 9 | ayan
# Processing Record 11 of Set 9 | nago
# Processing Record 12 of Set 9 | kontagora
# Processing Record 13 of Set 9 | giraltovce
# Processing Record 14 of Set 9 | tacna
# Processing Record 15 of Set 9 | zhezkazgan
# Processing Record 16 of Set 9 | bokspits
# City not found
# Processing Record 17 of Set 9 | hay river
# Processing Record 18 of Set 9 | kimbe
# Processing Record 19 of Set 9 | hastings
# Processing Record 20 of Set 9 | kunming
# Processing Record 21 of Set 9 | dandong
# Processing Record 22 of Set 9 | bougouni
# Processing Record 23 of Set 9 | rungata
# City not found
# Processing Record 24 of Set 9 | pop
# Processing Record 25 of Set 9 | pingxiang
# Processing Record 26 of Set 9 | mahon
# Processing Record 27 of Set 9 | bonnyville
# Processing Record 28 of Set 9 | berbera
# Processing Record 29 of Set 9 | conakry
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | serenje
# Processing Record 32 of Set 9 | pandan
# Processing Record 33 of Set 9 | tuatapere
# Processing Record 34 of Set 9 | lorengau
# Processing Record 35 of Set 9 | kavaratti
# Processing Record 36 of Set 9 | bargal
# City not found
# Processing Record 37 of Set 9 | ketchikan
# Processing Record 38 of Set 9 | pinega
# Processing Record 39 of Set 9 | boa vista
# Processing Record 40 of Set 9 | westport
# Processing Record 41 of Set 9 | deputatskiy
# Processing Record 42 of Set 9 | mountain home
# Processing Record 43 of Set 9 | krasnoyarsk-45
# City not found
# Processing Record 44 of Set 9 | ulladulla
# Processing Record 45 of Set 9 | mount gambier
# Processing Record 46 of Set 9 | henties bay
# Processing Record 47 of Set 9 | juegang
# Processing Record 48 of Set 9 | sao joao da barra
# Processing Record 49 of Set 9 | polson
# Processing Record 50 of Set 9 | banikoara
# Processing Record 1 of Set 10 | florianopolis
# Processing Record 2 of Set 10 | pangnirtung
# Processing Record 3 of Set 10 | iqaluit
# Processing Record 4 of Set 10 | leh
# Processing Record 5 of Set 10 | mocorito
# Processing Record 6 of Set 10 | vung tau
# Processing Record 7 of Set 10 | yunjinghong
# City not found
# Processing Record 8 of Set 10 | ust-koksa
# Processing Record 9 of Set 10 | otteveny
# Processing Record 10 of Set 10 | lerwick
# Processing Record 11 of Set 10 | copala
# Processing Record 12 of Set 10 | fandriana
# Processing Record 13 of Set 10 | haapiti
# Processing Record 14 of Set 10 | stornoway
# Processing Record 15 of Set 10 | gorno-chuyskiy
# City not found
# Processing Record 16 of Set 10 | bud
# Processing Record 17 of Set 10 | abu samrah
# Processing Record 18 of Set 10 | farmington
# Processing Record 19 of Set 10 | boissevain
# Processing Record 20 of Set 10 | biltine
# Processing Record 21 of Set 10 | mizdah
# Processing Record 22 of Set 10 | miandrivazo
# Processing Record 23 of Set 10 | bur gabo
# City not found
# Processing Record 24 of Set 10 | chapais
# Processing Record 25 of Set 10 | thai binh
# Processing Record 26 of Set 10 | dodge city
# Processing Record 27 of Set 10 | sabaudia
# Processing Record 28 of Set 10 | kaniama
# Processing Record 29 of Set 10 | atambua
# Processing Record 30 of Set 10 | mangaldai
# Processing Record 31 of Set 10 | hervey bay
# Processing Record 32 of Set 10 | mega
# Processing Record 33 of Set 10 | stoyba
# City not found
# Processing Record 34 of Set 10 | ballina
# Processing Record 35 of Set 10 | besikduzu
# Processing Record 36 of Set 10 | crepaja
# Processing Record 37 of Set 10 | hirna
# Processing Record 38 of Set 10 | aykhal
# Processing Record 39 of Set 10 | elizabeth city
# Processing Record 40 of Set 10 | kazalinsk
# City not found
# Processing Record 41 of Set 10 | caravelas
# Processing Record 42 of Set 10 | ghanzi
# Processing Record 43 of Set 10 | yumen
# Processing Record 44 of Set 10 | jawa
# Processing Record 45 of Set 10 | bhor
# Processing Record 46 of Set 10 | apt
# Processing Record 47 of Set 10 | aklavik
# Processing Record 48 of Set 10 | uroteppa
# City not found
# Processing Record 49 of Set 10 | tooele
# Processing Record 50 of Set 10 | ivanivka
# Processing Record 1 of Set 11 | isangel
# Processing Record 2 of Set 11 | nargana
# Processing Record 3 of Set 11 | alice springs
# Processing Record 4 of Set 11 | ostrovnoy
# Processing Record 5 of Set 11 | nhulunbuy
# Processing Record 6 of Set 11 | kapoeta
# Processing Record 7 of Set 11 | puerto montt
# Processing Record 8 of Set 11 | eregli
# Processing Record 9 of Set 11 | van buren
# Processing Record 10 of Set 11 | scottsbluff
# Processing Record 11 of Set 11 | nynashamn
# Processing Record 12 of Set 11 | kozhva
# Processing Record 13 of Set 11 | the valley
# Processing Record 14 of Set 11 | quatre cocos
# Processing Record 15 of Set 11 | talcahuano
# Processing Record 16 of Set 11 | srednekolymsk
# Processing Record 17 of Set 11 | leningradskiy
# Processing Record 18 of Set 11 | labuhan
# Processing Record 19 of Set 11 | daru
# Processing Record 20 of Set 11 | dunayivtsi
# City not found
# Processing Record 21 of Set 11 | felanitx
# Processing Record 22 of Set 11 | seara
# Processing Record 23 of Set 11 | verkhnyaya inta
# Processing Record 24 of Set 11 | atchison
# Processing Record 25 of Set 11 | palmer
# Processing Record 26 of Set 11 | timra
# Processing Record 27 of Set 11 | ca mau
# Processing Record 28 of Set 11 | saleaula
# City not found
# Processing Record 29 of Set 11 | mogadishu
# Processing Record 30 of Set 11 | hit
# Processing Record 31 of Set 11 | anadyr
# Processing Record 32 of Set 11 | tomari
# Processing Record 33 of Set 11 | avanigadda
# Processing Record 34 of Set 11 | erzin
# Processing Record 35 of Set 11 | harper
# Processing Record 36 of Set 11 | lufilufi
# Processing Record 37 of Set 11 | mudkhed
# Processing Record 38 of Set 11 | nsanje
# Processing Record 39 of Set 11 | narasannapeta
# Processing Record 40 of Set 11 | santa ana
# Processing Record 41 of Set 11 | birobidzhan
# Processing Record 42 of Set 11 | pijijiapan
# Processing Record 43 of Set 11 | cumaribo
# City not found
# Processing Record 44 of Set 11 | hohhot
# Processing Record 45 of Set 11 | luba
# Processing Record 46 of Set 11 | los llanos de aridane
# Processing Record 47 of Set 11 | ponta delgada
# Processing Record 48 of Set 11 | tadpatri
# Processing Record 49 of Set 11 | pasni
# Processing Record 50 of Set 11 | foz
# Processing Record 1 of Set 12 | phan rang
# City not found
# Processing Record 2 of Set 12 | liwonde
# Processing Record 3 of Set 12 | sur
# Processing Record 4 of Set 12 | kijang
# Processing Record 5 of Set 12 | general roca
# Processing Record 6 of Set 12 | wanaka
# Processing Record 7 of Set 12 | natchitoches
# Processing Record 8 of Set 12 | voloshka
# Processing Record 9 of Set 12 | karaul
# City not found
# Processing Record 10 of Set 12 | berlevag
# Processing Record 11 of Set 12 | klaksvik
# Processing Record 12 of Set 12 | lakatoro
# Processing Record 13 of Set 12 | port-cartier
# Processing Record 14 of Set 12 | sapouy
# Processing Record 15 of Set 12 | jhelum
# Processing Record 16 of Set 12 | avdon
# Processing Record 17 of Set 12 | lagoa
# Processing Record 18 of Set 12 | killybegs
# Processing Record 19 of Set 12 | sidi bu zayd
# City not found
# Processing Record 20 of Set 12 | okahandja
# Processing Record 21 of Set 12 | micheweni
# Processing Record 22 of Set 12 | dingle
# Processing Record 23 of Set 12 | olyka
# Processing Record 24 of Set 12 | mackay
# Processing Record 25 of Set 12 | el carmen
# Processing Record 26 of Set 12 | santiago del estero
# Processing Record 27 of Set 12 | heihe
# Processing Record 28 of Set 12 | waddan
# Processing Record 29 of Set 12 | miquelon
# Processing Record 30 of Set 12 | tigbinan
# Processing Record 31 of Set 12 | eyl
# Processing Record 32 of Set 12 | segalstad
# City not found
# Processing Record 33 of Set 12 | paucartambo
# City not found
# Processing Record 34 of Set 12 | havelock
# Processing Record 35 of Set 12 | mrirt
# City not found
# Processing Record 36 of Set 12 | hellvik
# Processing Record 37 of Set 12 | kholtoson
# Processing Record 38 of Set 12 | buala
# Processing Record 39 of Set 12 | gabu
# Processing Record 40 of Set 12 | waingapu
# Processing Record 41 of Set 12 | langxiang
# Processing Record 42 of Set 12 | fare
# Processing Record 43 of Set 12 | niceville
# Processing Record 44 of Set 12 | ughelli
# Processing Record 45 of Set 12 | tawkar
# City not found
# Processing Record 46 of Set 12 | artesia
# Processing Record 47 of Set 12 | beyneu
# Processing Record 48 of Set 12 | venado tuerto
# Processing Record 49 of Set 12 | xiaolingwei
# Processing Record 50 of Set 12 | new ulm
# Processing Record 1 of Set 13 | konotop
# Processing Record 2 of Set 13 | okha
# Processing Record 3 of Set 13 | gazanjyk
# Processing Record 4 of Set 13 | pierre
# Processing Record 5 of Set 13 | ambon
# Processing Record 6 of Set 13 | miraflores
# Processing Record 7 of Set 13 | plouzane
# Processing Record 8 of Set 13 | cuamba
# Processing Record 9 of Set 13 | camacha
# Processing Record 10 of Set 13 | vila franca do campo
# Processing Record 11 of Set 13 | karamea
# City not found
# Processing Record 12 of Set 13 | biloela
# Processing Record 13 of Set 13 | sao lourenco
# Processing Record 14 of Set 13 | salyan
# Processing Record 15 of Set 13 | lazaro cardenas
# Processing Record 16 of Set 13 | smithers
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 563

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City Country                 Date    Lat     Lng  \
# 0               New Norfolk      AU  2020-02-22 17:58:24 -42.78  147.06
# 1              Punta Arenas      CL  2020-02-22 17:54:49 -53.15  -70.92
# 2                    Avarua      CK  2020-02-22 17:58:25 -21.21 -159.78
# 3                  Bardiyah      LY  2020-02-22 17:58:25  31.76   25.09
# 4  Sao Gabriel Da Cachoeira      BR  2020-02-22 17:58:25  -0.13  -67.09
# 5                  Hermanus      ZA  2020-02-22 17:58:25 -34.42   19.23
# 6                      Nuuk      GL  2020-02-22 17:58:25  64.18  -51.72
# 7                Brigantine      US  2020-02-22 17:58:26  39.41  -74.36
# 8                     Arman      RU  2020-02-22 17:58:26  59.70  150.17
# 9                  Mabaruma      GY  2020-02-22 17:58:26   8.20  -59.78
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 0     53.60        81          40        3.36    scattered clouds
# 1     71.60        52         100       10.29     overcast clouds
# 2     82.40        83          93        8.05          light rain
# 3     57.00        74          58       18.43          light rain
# 4     82.40        88          75        2.24       broken clouds
# 5     66.00        99         100        1.99          light rain
# 6     15.80        61          75        5.82   light shower snow
# 7     48.99        17           1       11.41           clear sky
# 8     -1.19        94         100        4.03     overcast clouds
# 9     85.03        61          88        2.55          light rain
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                       0.0
# 1                      0.00                       0.0
# 2                      0.94                       0.0
# 3                      0.63                       0.0
# 4                      0.00                       0.0
# 5                      0.12                       0.0
# 6                      0.00                       0.0
# 7                      0.00                       0.0
# 8                      0.00                       0.0
# 9                      0.56                       0.0

# %%
#Save the new DataFrame as a CSV file to be used for Part 2.
city_data_df.to_csv('weather_data/WeatherPy_challenge.csv')

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563 entries, 0 to 562
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   City                      563 non-null    object
#  1   Country                   563 non-null    object
#  2   Date                      563 non-null    object
#  3   Lat                       563 non-null    float64
#  4   Lng                       563 non-null    float64
#  5   Max Temp                  563 non-null    float64
#  6   Humidity                  563 non-null    int64
#  7   Cloudiness                563 non-null    int64
#  8   Wind Speed                563 non-null    float64
#  9   Current Description       563 non-null    object
#  10  Rain inches (last 3 hrs)  563 non-null    float64
#  11  Snow inches (last 3 hrs)  563 non-null    float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 52.9+ KB

# %%
# Answer this question using Pandas methods: How many cities have recorded rainfall or snow?

# %%
len(city_data_df[city_data_df["Rain inches (last 3 hrs)"] >0 ])
# Out:
# 65

# %%
len(city_data_df[city_data_df["Snow inches (last 3 hrs)" ] >0 ])
# Out:
# 19
